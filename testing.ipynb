# %%
import pandas as pd

df = pd.read_csv("./chunked_press_review.csv")
df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: x.replace(" 00:00:00", "")))
articles = df.groupby(["Title", "Date", "Author", "Newspaper", "Source", "newspaper_type"])['chunks'].apply(lambda x: " ".join(x).replace("  ", " ")).reset_index()
articles = articles.sort_values(["Date"])
articles['time_frame'] = pd.to_datetime(articles['Date'])
articles['Title'] = articles["Title"].apply(lambda x: x.strip())

new_data = pd.read_csv("./extra_times_guadian_data.csv")
articles = pd.concat([articles, new_data], ignore_index=True)

# %%
name_map = {"guardian": "The Guardian", "times": "The Times"}
articles['Newspaper'] = articles['Newspaper'].apply(lambda x: name_map.get(x, x) if x in name_map else x)

# %%
articles.to_csv("./final_press_review.csv", index=False)

# %%
import pandas as pd

articles = pd.read_csv("./final_press_review.csv")

# %%
articles['time_frame'] = pd.to_datetime(articles['Date'], format='mixed')

# %%
subset = articles[articles.Newspaper == "The Guardian"]

# %%
subset[subset.Author == "No author"]
# Out:
#                                                    Title        Date  \
# 10105  Andy Burnham demands NHS contaminated blood in...   2017-4-26
# 10106  Contaminated blood survivor_ 'I think they jus...   2017-7-11
# 10107  Theresa May orders contaminated blood scandal ...   2017-7-11
# 10108  Mongolia's liver cancer crisis_ 'No other coun...   2017-11-7
# 10109  Competition and collaboration to cut the price...   2018-4-11
# 10110  The Tories' latest campaign tactic_ Blaming La...    2018-5-1
# 10111  'Treated like pariahs'_ contaminated blood vic...   2018-9-25
# 10112  Britain’s use of contaminated blood was no ‘tr...   2018-4-17
# 10113                              Zaire notifies deaths  1976-10-23
# 10114  Police accused of exaggerating risks of HIV to...  2017-11-17
# 10115                                   Piggyback plague   1984-11-8
# 10116  Why was contaminated blood allowed to devastat...   2018-9-27
# 10117  Hepatitis C antiviral drugs are effective _ Le...   2017-7-13
# 10118             Hepatitis could be caused by new virus   1977-1-24
# 10119  Infected blood victims 'may still not know the...   2018-9-24
# 10120  NHS tainted blood scandal_ victim payment sche...    2017-3-7
# 10121  'Miracle' hepatitis C drugs costing £30k per p...    2017-6-8
# 10122  To tackle the contaminated blood scandal, Brit...    2017-8-1
# 10123  Britain's contaminated blood scandal_ ‘I need ...    2018-3-3
# 10124  HIV, hepatitis, death_ infected blood scandal ...   2018-9-29
# 10125  Contaminated blood scandal victims allowed to ...   2017-9-26
# 10126  The Guardian view on the contaminated blood sc...   2017-7-13
# 10127  Deadly flaws in the US ‘cash for blood’ system...   2017-7-12
# 10128           Jaundice cases show unexplained increase    1981-8-5
# 10129  Andy Burnham urges Theresa May to rescue conta...   2017-8-31
# 10130  What is the contaminated blood scandal_ _ Soci...   2017-7-11
# 10131  Non-profit’s $300 hepatitis C cure as effectiv...   2018-4-12
#
#           Author     Newspaper          Source newspaper_type  \
# 10105  No author  The Guardian  Newspaper site     broadsheet
# 10106  No author  The Guardian  Newspaper site     broadsheet
# 10107  No author  The Guardian  Newspaper site     broadsheet
# 10108  No author  The Guardian  Newspaper site     broadsheet
# 10109  No author  The Guardian  Newspaper site     broadsheet
# 10110  No author  The Guardian  Newspaper site     broadsheet
# 10111  No author  The Guardian  Newspaper site     broadsheet
# 10112  No author  The Guardian  Newspaper site     broadsheet
# 10113  No author  The Guardian  Newspaper site     broadsheet
# 10114  No author  The Guardian  Newspaper site     broadsheet
# 10115  No author  The Guardian  Newspaper site     broadsheet
# 10116  No author  The Guardian  Newspaper site     broadsheet
# 10117  No author  The Guardian  Newspaper site     broadsheet
# 10118  No author  The Guardian  Newspaper site     broadsheet
# 10119  No author  The Guardian  Newspaper site     broadsheet
# 10120  No author  The Guardian  Newspaper site     broadsheet
# 10121  No author  The Guardian  Newspaper site     broadsheet
# 10122  No author  The Guardian  Newspaper site     broadsheet
# 10123  No author  The Guardian  Newspaper site     broadsheet
# 10124  No author  The Guardian  Newspaper site     broadsheet
# 10125  No author  The Guardian  Newspaper site     broadsheet
# 10126  No author  The Guardian  Newspaper site     broadsheet
# 10127  No author  The Guardian  Newspaper site     broadsheet
# 10128  No author  The Guardian  Newspaper site     broadsheet
# 10129  No author  The Guardian  Newspaper site     broadsheet
# 10130  No author  The Guardian  Newspaper site     broadsheet
# 10131  No author  The Guardian  Newspaper site     broadsheet
#
#                                                   chunks time_frame  \
# 10105  1/11/2019 Andy Burnham demands NHS contaminate... 2017-04-26
# 10106  Contaminated blood survivor: 'I think they jus... 2017-07-11
# 10107  The Guardian\nTheresa May orders contaminated ... 2017-07-11
# 10108  Mongolia's liver cancer crisis: 'No other coun... 2017-11-07
# 10109  The large graphic accompanying your article (T... 2018-04-11
# 10110  The Tories' latest campaign tactic? Blaming La... 2018-05-01
# 10111  'Treated like pariahs': contaminated blood vic... 2018-09-25
# 10112  The latest inquiry must discover how thousands... 2018-04-17
# 10113  Zaire notifies deaths\n\nFrom ROD CHAPMAN\n\nG... 1976-10-23
# 10114  The Guardian\n\nPolice accused of exaggerating... 2017-11-17
# 10115  Peggyback Plague\nBy David Dyer\nLondon\n\nThe... 1984-11-08
# 10116  The Guardian\nWhy was contaminated blood allow... 2018-09-27
# 10117  1/11/2019\nHepatitis C antiviral drugs are eff... 2017-07-13
# 10118  Hepatitis could be caused by new viruses By ou... 1977-01-24
# 10119  Infected blood victims 'may still not know the... 2018-09-24
# 10120  NHS tainted blood scandal: victim payment sche... 2017-03-07
# 10121  1/11/2019 'Miracle' hepatitis C drugs costing ... 2017-06-08
# 10122  To tackle the contaminated blood scandal, Brit... 2017-08-01
# 10123  Britain's contaminated blood scandal: 'I need ... 2018-03-03
# 10124  Red for HIV, yellow for hepatitis, black for d... 2018-09-29
# 10125  Contaminated blood scandal victims allowed to ... 2017-09-26
# 10126  The Guardian view on the contaminated blood sc... 2017-07-13
# 10127  Deadly flaws in the US 'cash for blood' system... 2017-07-12
# 10128  Jaundice cases show\nunexplained increase\n\nB... 1981-08-05
# 10129  The mayor of Greater Manchester, Andy Burnham,... 2017-08-31
# 10130  What is the contaminated blood scandal?\n\nKey... 2017-07-11
# 10131  Non-profit's $300 hepatitis C cure as effectiv... 2018-04-12
#
#        Unnamed: 0
# 10105         0.0
# 10106         1.0
# 10107         2.0
# 10108         3.0
# 10109         4.0
# 10110         5.0
# 10111         6.0
# 10112         7.0
# 10113         8.0
# 10114         9.0
# 10115        10.0
# 10116        11.0
# 10117        12.0
# 10118        13.0
# 10119        14.0
# 10120        15.0
# 10121        16.0
# 10122        17.0
# 10123        18.0
# 10124        19.0
# 10125        20.0
# 10126        21.0
# 10127        22.0
# 10128        23.0
# 10129        24.0
# 10130        25.0
# 10131        26.0

# %%
subset_yearly = subset.groupby(subset['time_frame'].dt.to_period('Y')).size()
subset_yearly
# Out:
# time_frame
# 1984     5
# 1989     7
# 1990     3
# 1993    11
# 1994     9
# 1995    18
# 1996    25
# 1997    24
# 1998    16
# 1999    22
# 2000    41
# 2001    69
# 2002    54
# 2003    23
# 2004    14
# 2005    34
# 2006    22
# 2007    70
# 2008    13
# 2009    20
# 2010    18
# 2011    11
# 2012    11
# 2013    15
# 2014    27
# 2015    37
# 2016    42
# 2017    47
# 2018    61
# 2019    78
# 2020    64
# 2021    37
# 2022    49
# 2023    41
# 2024    34
# Freq: Y-DEC, dtype: int64
